# %%
import pandas as pd

# %%
df = pd.read_csv("../data/external/eth_addresses.csv")

# %%
df.head(100)
# Out:
#                                        Address                        Name  \
# 0   0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7            Akropolis (AKRO)
# 1   0x1c74cff0376fb4031cd7492cd6db2d66c3f2c6b9   bZx Protocol Token (BZRX)
# 2   0x06af07097c9eeb7fd685c692751d5c66db49c215                 Chai (CHAI)
# 3   0xc00e94cb662c3520282e6f5717214004a7f26888             Compound (COMP)
# 4   0xb3319f5d18bc0d84dd1b4825dcde5d5f7266d407          Compound 0x (cZRX)
# ..                                         ...                         ...
# 95  0x8052cccc713cc9883afb1a9d863fe165e08dff01    AaveFinancialOpportunity
# 96  0x2732e2a7bfaa8e5a21c07f4f1c167bbfbf7a2ac1             AaveIntegration
# 97  0x0db084f8ba9bc1176fd9b43e664072ad660bc61a               AaveLiquidate
# 98  0x1b846e9159104430775e1852ec7ac6a1b4760783               AaveLiquidate
# 99  0x1f916d0766c7f20b1a51086724f55ccfd07d2f3c               AaveLiquidate
#
#       Account Type Contract Type Entity  Label               Tags  \
# ...

# %%
df.Entity.value_counts()
# Out:
# DeFi           1046
# Exchange        249
# ICO Wallets     161
# Mining          108
# Dex              81
# Entity            1
# Name: Entity, dtype: int64

# %%
df = df[["Address", "Entity"]]

# %%
df.head()
# Out:
#                                       Address Entity
# 0  0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7   DeFi
# 1  0x1c74cff0376fb4031cd7492cd6db2d66c3f2c6b9   DeFi
# 2  0x06af07097c9eeb7fd685c692751d5c66db49c215   DeFi
# 3  0xc00e94cb662c3520282e6f5717214004a7f26888   DeFi
# 4  0xb3319f5d18bc0d84dd1b4825dcde5d5f7266d407   DeFi

# %%
df = df[df.Entity != "Entity"]

# %%
df.Entity.value_counts()
# Out:
# DeFi           1046
# Exchange        249
# ICO Wallets     161
# Mining          108
# Dex              81
# Name: Entity, dtype: int64

# %%
df.head()
# Out:
#                                       Address Entity
# 0  0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7   DeFi
# 1  0x1c74cff0376fb4031cd7492cd6db2d66c3f2c6b9   DeFi
# 2  0x06af07097c9eeb7fd685c692751d5c66db49c215   DeFi
# 3  0xc00e94cb662c3520282e6f5717214004a7f26888   DeFi
# 4  0xb3319f5d18bc0d84dd1b4825dcde5d5f7266d407   DeFi

# %%
df.to_csv("../data/processed/eth_addresses_labels.csv", index_label=False)
