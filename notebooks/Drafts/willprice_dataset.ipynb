# %%
import pickle

# %%
data = pickle.load(open("../data/external/df.p", "rb"))

# %%
data.head(100)
# Out:
#                                        address  outgoing_txns  incoming_txns  \
# 0   0xd26a4d3ce34eef62a5eacc1f07b6e4ed11d0d516            256            151
# 1   0x5730d1ea8624b745dde30e57d7f6e8f83fcec98a            256             56
# 2   0x1efc1e054f14aa9ab69e71c8f181d4b8f4005735            256            104
# 3   0xfd3a935174aeb79b8d5d3935de1188e37427561f            768            892
# 4   0xf27b5cf6d40531556f6e6eeb445a8c88c8f9815f           1024           9860
# ..                                         ...            ...            ...
# 95  0xa315dc78f1285fc3148a32a742c715ec7e88c997              3             14
# 96  0xa752be3c0b94532ab2fa20feb48eec60c1d20cdf              3             15
# 97  0xb125ca2c8eea1c8a8963f860a2f43475d800d40c              3             16
# 98  0x46c502c1625b4c7464b43f5913236e710095aaf3              3             24
# 99  0x5f16d921c19ba1333ae1609ee8090fb2a581317b              3             29
#
# ...

# %%
data.shape
# Out:
# (35917, 26)

# %%
data_2 = pickle.load(open("../data/external/dfsummary.p", "rb"))

# %%
data_2.head()
# Out:
#    outgoing_txns  incoming_txns  total_eth_sent  avg_eth_sent  total_usd_sent  \
# 0       7.076342       9.799170       23.132883      3.814353    8.709742e+03
# 1      16.705794      19.170321     4021.831396    248.887793    1.671981e+06
# 2      10.922637     167.336320       49.598236      5.309813    2.060551e+04
# 4      10.131347      11.422883      270.418856     27.889034    1.169501e+05
# 5       5.084728       8.848053       23.576924      6.552525    5.891108e+03
#
#     avg_usd_sent  total_eth_recd  avg_eth_recd  total_usd_recd   avg_usd_recd  \
# 0    1284.102539      105.241742     11.439569    3.079417e+04    3223.280701
# 1  103157.679659     6079.873128    329.608474    1.923413e+06  103894.253069
# 2    1951.796638      141.254943      1.224849    4.901279e+04     298.985664
# 4   11860.148445      492.328926     44.725116    1.409067e+05   12654.466003
# 5    1332.700011      191.536119     23.704531    5.684290e+04    6676.064819
#
# ...
